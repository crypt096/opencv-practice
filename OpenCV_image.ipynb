# %% [markdown]
# <a href="https://colab.research.google.com/github/crypt096/opencv-practice/blob/main/OpenCV_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import random
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('cat_image.jpeg', -1)

# %%
tag = img[300:500, 600:900]

# %%
img[100:300, 150:450] = tag

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=976x549 at 0x7FB7043448D0>
